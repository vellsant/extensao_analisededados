# %% [markdown]
# <a href="https://colab.research.google.com/github/vellsant/extensao_analisededados/blob/main/Exetens%C3%A3oAn%C3%A1liseDeDados_Exemplo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Segundo Exemplo de Manipulação de Dados com Python Pandas <br>**
# *Realizado durante o curso de extensão "Análise de Dados com Python Pandas (Básico)* <br>
# *Ministrado pelo professor Henrique Poyatos* <br>
# **Aluna**: Amanda Rodrigues Velloso Santana - UAM

# %%
#Importando a biblioteca Pandas
import pandas as pd

# %%
#Criando o Dataframe 'combustiveis_df'
combustiveis_df = pd.read_excel("/content/ca-2021-02.xlsx")
display(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#Inserção simples de dados
combustiveis_df['Ativo'] = True
print(combustiveis_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
#Criar uma coluna "OBS" que tenha escrito "MELHOR CIDADE" quando a coluna MUNICIPIO for igual a SANTOS
combustiveis_df['OBS'] = ["MELHOR CIDADE" if municipio == 'SANTOS' else '' for municipio in combustiveis_df['Municipio']]
display(combustiveis_df.loc[combustiveis_df['Municipio'].isin(['SANTOS', 'PRAIA GRANDE']),['Municipio', 'OBS']])
# Out:
#            Municipio            OBS
# 1557          SANTOS  MELHOR CIDADE
# 1558          SANTOS  MELHOR CIDADE
# 1559          SANTOS  MELHOR CIDADE
# 1560          SANTOS  MELHOR CIDADE
# 1561          SANTOS  MELHOR CIDADE
# ...              ...            ...
# 162160  PRAIA GRANDE
# 162161  PRAIA GRANDE
# 162162  PRAIA GRANDE
# 162163  PRAIA GRANDE
# 162164  PRAIA GRANDE
#
# [929 rows x 2 columns]

# %%
#Preenchendo uma coluna 'Valor de Venda - Status' quer verifica:
#Valor de Venda > 6,5 = CARO
#Do contrário, BARATO

import numpy as np

combustiveis_df['Valor de Venda - Status'] = np.where(combustiveis_df['Valor de Venda'] > 6.5, 'CARO', 'BARATO')
display(combustiveis_df[['Municipio','Revenda','Valor de Venda', 'Valor de Venda - Status']])
# Out:
#         Municipio                                     Revenda  Valor de Venda  \
# 0       ARAPIRACA                        POSTO ARAPIRACA LTDA           6.799
# 1       ARAPIRACA                        POSTO ARAPIRACA LTDA           5.299
# 2       ARAPIRACA                        POSTO ARAPIRACA LTDA           5.549
# 3       ARAPIRACA                        POSTO ARAPIRACA LTDA           6.899
# 4       ARAPIRACA                        POSTO ARAPIRACA LTDA           5.649
# ...           ...                                         ...             ...
# 168404     JEQUIE  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA           5.859
# 168405  ITUIUTABA           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
# 168406  ITUIUTABA           ABC DISTRIBUICAO DE PETROLEO LTDA           4.740
# 168407  ITUIUTABA           ABC DISTRIBUICAO DE PETROLEO LTDA           5.448
# 168408  ITUIUTABA           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
#
#        Valor de Venda - Status
# ...

# %%
#Calcular postos de gasolina por habitante que temos na amostragem de combustiveis de nov/21
num_habitantes_df = pd.read_csv("/content/ibge_num_habitantes_estimado.csv", sep=";")
display(num_habitantes_df)
# Out:
#          Municipio Estado  NumHabitantes2021
# 0   BELO HORIZONTE     MG            2530701
# 1         CAMPINAS     SP            1223237
# 2     CAMPO GRANDE     MS             916001
# 3         CURITIBA     PR            1963726
# 4          GOIANIA     GO            1555626
# 5       INDAIATUBA     SP             260690
# 6            NATAL     RN             803739
# 7           PALMAS     TO             313349
# 8        PENAPOLIS     SP              64098
# 9     PORTO ALEGRE     RS            1492530
# 10     PORTO VELHO     RO             548952
# 11      RIO BRANCO     AC             419452
# 12  RIO DE JANEIRO     RJ            6775561
# 13    SALTO GRANDE     SP               9396
# 14          SANTOS     SP             433991
# 15       SAO PAULO     SP           12396372
# 16     SAO VICENTE     SP             370839
# 17     SERRA NEGRA     SP              29669

# %%
#Alterar o nome da coluna 'Estado' no dataframe 'num_habitantes_df'
num_habitantes_df.rename(columns={"Estado":"Estado - Sigla"}, inplace=True)
display(num_habitantes_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# ...

# %%
#Fazer um MERGE entre dois Dataframes
colunas=['Municipio', 'Estado - Sigla']
merge_df = combustiveis_df.merge(num_habitantes_df,  how="inner", on=colunas)
display(merge_df)
print(merge_df.info())
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...

# %%
#Destruir coluna totalmente vazia
merge_df.dropna(axis='columns',inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Regiao - Sigla           20634 non-null  object
#  1   Estado - Sigla           20634 non-null  object
#  2   Municipio                20634 non-null  object
#  3   Revenda                  20634 non-null  object
#  4   CNPJ da Revenda          20634 non-null  object
#  5   Nome da Rua              20634 non-null  object
#  6   Numero Rua               20634 non-null  object
#  7   Bairro                   20634 non-null  object
#  8   Cep                      20634 non-null  object
#  9   Produto                  20634 non-null  object
#  10  Data da Coleta           20634 non-null  datetime64[ns]
#  11  Valor de Venda           20634 non-null  float64
#  12  Unidade de Medida        20634 non-null  object
# ...

# %%
#Destruir colunas específicas
colunas=['Regiao - Sigla','Nome da Rua', 'Numero Rua', 'Bairro', 'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda', 'Unidade de Medida', 'Bandeira', 'Ativo', 'Valor de Venda - Status']

merge_df.drop(labels=colunas, axis=1, inplace=True)

# %%
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Estado - Sigla     20634 non-null  object
#  1   Municipio          20634 non-null  object
#  2   Revenda            20634 non-null  object
#  3   CNPJ da Revenda    20634 non-null  object
#  4   OBS                20634 non-null  object
#  5   NumHabitantes2021  20634 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 1.1+ MB
# None

# %%
display(merge_df.head(100))
# Out:
#    Estado - Sigla Municipio                       Revenda  \
# 0              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 1              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 2              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 3              GO   GOIANIA             POSTO DO BOI LTDA
# 4              GO   GOIANIA             POSTO DO BOI LTDA
# ..            ...       ...                           ...
# 95             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 96             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 97             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 98             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 99             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
#
#         CNPJ da Revenda OBS  NumHabitantes2021
# 0    37.831.484/0001-20                1555626
# 1    37.831.484/0001-20                1555626
# 2    37.831.484/0001-20                1555626
# 3    06.880.293/0001-25                1555626
# ...

# %%
#Deletar as linhas duplicadas
merge_df.drop_duplicates(inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1532 entries, 0 to 20608
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Estado - Sigla     1532 non-null   object
#  1   Municipio          1532 non-null   object
#  2   Revenda            1532 non-null   object
#  3   CNPJ da Revenda    1532 non-null   object
#  4   OBS                1532 non-null   object
#  5   NumHabitantes2021  1532 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 83.8+ KB
# None

# %%
display(merge_df.head(100))
# Out:
#      Estado - Sigla       Municipio                                   Revenda  \
# 0                GO         GOIANIA                 AERO SETE AUTO POSTO LTDA
# 3                GO         GOIANIA                         POSTO DO BOI LTDA
# 7                GO         GOIANIA                             POSTO DN LTDA
# 11               GO         GOIANIA                         POSTO ALDEIA LTDA
# 15               GO         GOIANIA               AUTO POSTO SANTA LUZIA LTDA
# ...             ...             ...                                       ...
# 1677             RJ  RIO DE JANEIRO       POSTO SANTA CLARA DA PAVUNA II LTDA
# 1682             RJ  RIO DE JANEIRO          POSTO SANTA CLARA DA PAVUNA LTDA
# 1688             RJ  RIO DE JANEIRO            NOVA PARADINHA AUTO POSTO LTDA
# 1694             RJ  RIO DE JANEIRO            AUTO POSTO LUAR DA PENHA LTDA.
# 1699             RJ  RIO DE JANEIRO  AUTO POSTO FUTURO GNV DE BONSUCESSO LTDA
#
# ...

# %%
merge_df.drop(labels='OBS',axis=1,inplace=True)

# %%
#Agrupar e contar quantos postos tem ans cidades
postos_por_municipio_df=merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()

postos_por_municipio_df.rename(columns={"Revenda":"Numero de Postos"}, inplace=True)

display(postos_por_municipio_df)
# Out:
#                                                  Numero de Postos  \
# Estado - Sigla Municipio      NumHabitantes2021
# AC             RIO BRANCO     419452                           44
# GO             GOIANIA        1555626                          93
# MG             BELO HORIZONTE 2530701                          54
# MS             CAMPO GRANDE   916001                          104
# PR             CURITIBA       1963726                         110
# RJ             RIO DE JANEIRO 6775561                         379
# RN             NATAL          803739                           37
# RO             PORTO VELHO    548952                           40
# RS             PORTO ALEGRE   1492530                          73
# SP             CAMPINAS       1223237                          51
#                INDAIATUBA     260690                           36
#                SANTOS         433991                           36
# ...

# %%
print(postos_por_municipio_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 15 entries, ('AC', 'RIO BRANCO', 419452) to ('TO', 'PALMAS', 313349)
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Numero de Postos  15 non-null     int64
#  1   CNPJ da Revenda   15 non-null     int64
# dtypes: int64(2)
# memory usage: 800.0+ bytes
# None
