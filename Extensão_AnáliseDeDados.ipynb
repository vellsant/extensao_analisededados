# %% [markdown]
# <a href="https://colab.research.google.com/github/vellsant/extensao_analisededados/blob/main/Extens%C3%A3o_An%C3%A1liseDeDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - 06/02/2023

# %% [markdown]
# **Primeiro exemplo de manipulação de dados usando Python Pandas** <br>
# Autor: Amanda Velloso <br>
# Data: 6 de Fevereiro de 2023

# %%
# Importando biblioteca Pandas no Python
import pandas as pd

# %%
#Cria o Dataframe com as informações no CSV. 
combustiveis_df = pd.read_csv("/content/precos-semestrais-ca-2022-01.csv", sep=";")

# %%
display(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla   Municipio  \
# 0                   N             AC  RIO BRANCO
# 1                   N             AC  RIO BRANCO
# 2                   N             AC  RIO BRANCO
# 3                   N             AC  RIO BRANCO
# 4                   N             AC  RIO BRANCO
# ...               ...            ...         ...
# 529419             CO             MT      CUIABA
# 529420             NE             MA      CAXIAS
# 529421             NE             MA      CAXIAS
# 529422             NE             MA      CAXIAS
# 529423             NE             MA      CAXIAS
#
#                                      Revenda      CNPJ da Revenda  \
# 0                  AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# 1                  AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# 2                  AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# 3                  AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# ...

# %%
display(combustiveis_df.head(10))
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio                    Revenda  \
# 0              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 1              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 2              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 3              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 4              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 5              N             AC  RIO BRANCO     AUTO POSTO ACAUAN LTDA
# 6              N             AC  RIO BRANCO     AUTO POSTO ACAUAN LTDA
# 7              N             AC  RIO BRANCO     AUTO POSTO ACAUAN LTDA
# 8              N             AC  RIO BRANCO     AUTO POSTO ACAUAN LTDA
# 9              N             AC  RIO BRANCO     AUTO POSTO ACAUAN LTDA
#
#        CNPJ da Revenda       Nome da Rua Numero Rua Complemento     Bairro  \
# 0   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN      AREAL
# ...

# %%
#Número de linhas e colunas
print(combustiveis_df.shape)

#Número de colunas, apenas
print(combustiveis_df.shape[0])
# Out:
# (529424, 16)
# 529424

# %%
#Estatísticas básicas
print(combustiveis_df.describe())
# Out:
#        Valor de Compra
# count              0.0
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN
